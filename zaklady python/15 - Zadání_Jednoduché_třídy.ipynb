# %% [markdown]
# #1. Zadání
#
# Vytvořte třídu Člověk, která bude mít atributy:
#
#
# 1.   jméno:str
# 2.   příjmení:str
# 3.   telefon:int
# 4.   email:str
# 5. adresa:str
# 6. pojišťovna:str
#
# Vytvořte metody, které budou moc získávat a měnit tyto atributy. Také vytvořte metodu, která vám vypíše vše o této osobě

# %%
class Clovek:
    def __init__(self,jmeno:str, prijmeni,telefon, email,adresa,pojistovna):
        self.jmeno= jmeno
        self.prijmeni=prijmeni
        self.telefon=telefon
        self.email=email
        self.adresa=adresa
        self.pojistovna=pojistovna
    def get_jmeno(self):
        return self.jmeno
    def set_jmeno(self,nove_jemeno):
        self.jmeno=nove_jemeno
        print("Jmeno bylo změněno")


    def get_primeni(self):
        return self.prijmeni
    def set_prijmeni(self,prijmeni):
        self.prijmeni= prijmeni
        print("Prijmeni bylo změněno")


    def get_telefon(self):
        if len(self.telefon)==9:
            return self.telefon
        else:
            print("špatně zadaný telefon")
    def set_telefon(self,telefon):
        self.telefon=telefon
        print("telefon byl změněn")


    def get_email(self):
        if "@" in self.email==False:
            print("neplatný email")
        else:
            return self.email


    def set_email(self,email):
        self.email=email
        print("email byl změněn")



    def get_adresa(self):
        return self.adresa
    def set_adresa(self,adresa):
        self.adresa=adresa
        print("adresa byla změněna")


    def get_pojistovna(self):
        return self.pojistovna
    def set_pojistovna(self, pojistovna):
        self.pojistovna=pojistovna
        print("pojistovna byla změněna")
    

    def __str__(self):
        return f"""
        Jméno: {self.jmeno} 
        Příjmení:{self.prijmeni}   
        telefon: {self.telefon}
        Email: {self.email}
        Adresa: {self.adresa}
        Pojistovna: {self.pojistovna}
"""
clovek1= Clovek ("Aneta","Koudelkova",1234567891,"asfaewfspskladno.cz","jahods 12", "VZP")
clovek1= Clovek ("Afeef","Kfefeoudelkova",85383434,"asfaewf@spskladno.cz","jahods 12", "VZP")
print(clovek1)
clovek1.set_prijmeni("Nesmysl")
print(clovek1)
print(clovek1.get_jmeno())
# Out:
#         Jméno: Afeef
#         Příjmení:Kfefeoudelkova
#         telefon: 85383434
#         Email: asfaewf@spskladno.cz
#         Adresa: jahods 12
#         Pojistovna: VZP
#
# Prijmeni bylo změněno
#
#         Jméno: Afeef
#         Příjmení:Nesmysl
#         telefon: 85383434
#         Email: asfaewf@spskladno.cz
#         Adresa: jahods 12
#         Pojistovna: VZP
#
# Afeef

# %%
# Out:
# aneta
# Jméno změněno.
# Karel
#
# Jméno: Karel
# Prijmeni: a
# Telefon: 456
# Email: ah@as.cz
# Adresa: VZP
# Pojistovna: VZP
# Mesto: Kladno

# %% [markdown]
# #2. Zadání
#
# upravte třídu Člověk tak, abyste ošetřili následující atributy:
#
#
# 1.   jméno:str
# 2.   příjmení:str
# 3.   telefon:int (maximálně 9 znaků)
# 4.   email:str (musí obsahovat @)
# 5. adresa:str
# 6. pojišťovna:str
#
# Upravte metody, které budou moc měnit tyto atributy i s aplikovanými omezeními.

# %%
class Clovek:
    def __init__(self, jmeno: str, prijmeni: str, telefon: int,
                 email: str, adresa: str, pojistovna: str):

        self.set_jmeno(jmeno)
        self.set_prijmeni(prijmeni)
        self.set_telefon(telefon)
        self.set_email(email)
        self.set_adresa(adresa)
        self.set_pojistovna(pojistovna)

    def get_jmeno(self):
        return self.jmeno

    def set_jmeno(self, jmeno):
        self.jmeno = jmeno
        return self.jmeno

    def get_prijmeni(self):
        return self.prijmeni

    def set_prijmeni(self, prijmeni):
        self.prijmeni = prijmeni
        return self.prijmeni

    def get_telefon(self):
        return self.telefon

    def set_telefon(self, telefon):
        telefon = (telefon)
        if len(telefon) == 9:
            self.telefon = telefon
            return self.telefon
        self.telefon = None
        return None

    def get_email(self):
        return self.email

    def set_email(self, email):
        if "@" in email:
            self.email = email
            return self.email
        self.email = None
        return None

    def get_adresa(self):
        return self.adresa

    def set_adresa(self, adresa):
        self.adresa = adresa
        return self.adresa

    def get_pojistovna(self):
        return self.pojistovna

    def set_pojistovna(self, pojistovna):
        self.pojistovna = pojistovna
        return self.pojistovna

    def __str__(self):
        return (f"""
            Jméno: {self.jmeno}
            Příjmení: {self.prijmeni}
            Telefon: {self.telefon}
            Email: {self.email}
            Adresa: {self.adresa}
            Pojistovna: {self.pojistovna}
        """)

clovek1 = Clovek(
    "Aneta",
    "Koudelkova",
    "123456789",
    "testsps@kladno.cz",
    "Jahodová 12",
    "VZP"
)

print(clovek1)

clovek2 = Clovek(
    "Pepa",
    "Novák",
    "12345",         
    "@email.cz",       
    "Brno",
    "VOZP"
)

print("Chybné hodnoty:")
print(clovek2)
# Out:
#             Jméno: Aneta
#             Příjmení: Koudelkova
#             Telefon: 123456789
#             Email: testsps@kladno.cz
#             Adresa: Jahodová 12
#             Pojistovna: VZP
#
# Chybné hodnoty:
#
#             Jméno: Pepa
#             Příjmení: Novák
#             Telefon: None
#             Email: @email.cz
#             Adresa: Brno
#             Pojistovna: VOZP

# %%
#Zde vytvořte alespoň 2 lidi a zkuste si všechny metody na jedné z nich

# %% [markdown]
# #3. Zadání
#
# Vytvořte třídu pojištovna, která bude mít atributy:
#
#
# 1.   název:str
# 2.   zkratkaPojištovny:str (maximálně 3 znaky)
# 3. sídlo:str
#
# Vytvořte metody, které budou moc získávat a měnit tyto atributy. Také vytvořte metodu, která vám vypíše vše o této pojišťovně.

# %%
class Pojistovna:
  #TODO

# %%
#Zde vytvořte alespoň 2 pojišťovny a zkuste si všechny metody na jedné z nich

# %% [markdown]
# #4. Zadání
#
# Upravte třídu Člověk tak, aby atribut pojišťovna byl vložen jako třída Pojišťovna
#
#
# 1.   jméno:str
# 2.   příjmení:str
# 3.   telefon:int (maximálně 9 znaků)
# 4.   email:str (musí obsahovat @)
# 5. adresa:str
# 6. pojišťovna:class(Pojišťovna)
#
# Upravte metodu, která vám vypíše vše o této osobě tak, aby Vám také vypsala všechny informace o dané pojišťovně

# %%
class Clovek:
  #TODO

# %%
#Zde vytvořte alespoň 2 lidi a zkuste si všechny metody na jedné z nich
print(karel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 #Zde vytvořte alespoň 2 lidi a zkuste si všechny metody na jedné z nich
# ----> 2 print(karel)
#
# NameError: name 'karel' is not defined

# %% [markdown]
# Ukázka Výstupu:
# ```
# Telefon, který jste zadali je neplatný
# Email, který jste zadali je neplatný
#
#         Jméno: Karel
#         Příjmení: Hympa
#         Telefon:
#         Email:
#         Adresa: Svatojánská 36
#         Pojišťovna: VZP
#
#
#         Jméno: Jarda
#         Příjmení: Klomajz
#         Telefon: 987654321
#         Email: Jarda@seznam.cz
#         Adresa: Svatojánská 37
#         Pojišťovna:
#         Název: Všeobecná pojišťovna
#         Zkratka: VZP
#         Sídlo: Armádní 93
# ```

# %% [markdown]
# # Počasí
#
# Vytvořte třídu Pocasi, která bude mít atributy:
#
# 1.   vítr:float
# 2.   povetrnostniPodminky:str
# 3.   teplota:float
# 4.   vlhkost:float
#
# Vytvořte metody, které budou moc získávat a měnit tyto atributy. Také vytvořte metodu, která vám vypíše vše tomto počasí

# %%
class Pocasi:
    #TODO

# %%
#Zde vytvořte alespoň 2 záznamy počasí a zkuste si všechny metody na jedné z nich

# %% [markdown]
# Ukázka Výstupu:
#
# ```
# Rychlost větru: 17 km/h
# Teplota: 18 °C
# Vlhost vzduchu: 54 %
# Počasí: Zataženo
# ```

# %% [markdown]
# # Počasí
# Upravte třídu Pocasi, aby přijímala Enum (na výběr z: Slunečno, zataženo, bouřky atd.)
